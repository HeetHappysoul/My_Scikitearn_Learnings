# %% [markdown]
# <a href="https://colab.research.google.com/github/HeetHappysoul/My_Scikitearn_Learnings/blob/main/Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
iris = load_iris()
X ,y = iris.data , iris.target
xtr,xte,ytr,yte = train_test_split(X,y,train_size = 0.3,random_state = 42)
rf = RandomForestClassifier(n_estimators = 1000,max_depth = 500)

rf.fit(xtr,ytr)
print(rf.score(xte,yte))
print(iris.feature_names , rf.feature_importances_)
# Out:
# 0.9428571428571428
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'] [0.06056296 0.06110207 0.36445056 0.5138844 ]
