# %% [markdown]
# <a href="https://colab.research.google.com/github/HeetHappysoul/My_Scikitearn_Learnings/blob/main/sci_kit_learn_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn, numpy as np , pandas as pd

# %%
print(sklearn.__version__)
print("done")
# Out:
# 1.6.1
# done

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_regression

# %%
x = np.array([[1],[2],[3],[4],[5]])
print(x.shape)
x.reshape(-1,1)
print(x.shape)
x.reshape(1,-1)
print(x.shape)

y = np.array([1,2,3,4,5])
print(y.reshape(-1,1).shape)
print(y.shape)
# Out:
# (5, 1)
# (5, 1)
# (5, 1)
# (5, 1)
# (5,)

# %%
a = np.array([[4],[5],[10],[1000],[200]])
b = np.array([3,4,44,66,77])
model = LinearRegression()
model.fit(a,b)
print(model.coef_)
print(model.intercept_)
print(model.predict([[1502]]))
# Out:
# [0.04653726]
# 27.454216495133977
# [97.35317804]
